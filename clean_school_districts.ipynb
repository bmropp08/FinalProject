# %%
import pandas as pd

# Replace 'file_path.csv' with the actual path to your CSV file.
file_path = 'Public_School_Characteristics_2020-21.csv'

# Use pandas.read_csv() to read the CSV file into a DataFrame.
# By default, the first row of the CSV will be treated as the header row.
# If your CSV file has no header, you can use `header=None` as an argument.
# If you want to specify a custom separator, you can use the `sep` parameter (e.g., sep=';').
data_frame = pd.read_csv(file_path)

# Now you can work with the data stored in the DataFrame.
# For example, you can display the first few rows using the `head()` method:
data_frame.head()
# Out:
# C:\Users\aspen\AppData\Local\Temp\ipykernel_13628\4109943986.py:10: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frame = pd.read_csv(file_path)
#            X        Y  OBJECTID      NCESSCH   SURVYEAR STABR   LEAID  \
# 0 -86.206200  34.2602         1  10000500870  2020-2021    AL  100005
# 1 -86.204900  34.2622         2  10000500871  2020-2021    AL  100005
# 2 -86.220100  34.2733         3  10000500879  2020-2021    AL  100005
# 3 -86.221806  34.2527         4  10000500889  2020-2021    AL  100005
# 4 -86.193300  34.2898         5  10000501616  2020-2021    AL  100005
#
#   ST_LEAID          LEA_NAME                           SCH_NAME  ...  HIALF  \
# 0   AL-101  Albertville City          Albertville Middle School  ...  230.0
# 1   AL-101  Albertville City            Albertville High School  ...  371.0
# 2   AL-101  Albertville City    Albertville Intermediate School  ...  253.0
# ...

# %%
#dropping multuple columns
columns_to_drop = ['OBJECTID', 'NCESSCH', 'SURVYEAR', 'LEAID', 'ST_LEAID', 'HIALF', 'HI', 'TRALM', 'TRALF', 'TR', 'WHALF', 'WHALM','WH']
data_frame = data_frame.drop(columns_to_drop, axis=1)
data_frame.head()
# Out:
#            X        Y STABR          LEA_NAME  \
# 0 -86.206200  34.2602    AL  Albertville City
# 1 -86.204900  34.2622    AL  Albertville City
# 2 -86.220100  34.2733    AL  Albertville City
# 3 -86.221806  34.2527    AL  Albertville City
# 4 -86.193300  34.2898    AL  Albertville City
#
#                             SCH_NAME             LSTREET1 LSTREET2  \
# 0          Albertville Middle School    600 E Alabama Ave      NaN
# 1            Albertville High School     402 E McCord Ave      NaN
# 2    Albertville Intermediate School   901 W McKinney Ave      NaN
# 3      Albertville Elementary School   145 West End Drive      NaN
# 4  Albertville Kindergarten and PreK  257 Country Club Rd      NaN
#
#          LCITY LSTATE   LZIP  ...   AS BLALM BLALF    BL HPALM HPALF   HP  \
# 0  Albertville     AL  35950  ...  4.0  18.0  15.0  33.0   0.0   0.0  0.0
# 1  Albertville     AL  35950  ...  6.0  33.0  37.0  70.0   0.0   0.0  0.0
# ...

# %%
columns_to_drop = ['LSTREET1', 'LSTREET2', 'AS', 'BLALM', 'BLALF', 'BL', 'HPALM', 'HPALF', 'HP', 'HIALM']
data_frame = data_frame.drop(columns_to_drop, axis=1)
data_frame.head()
# Out:
#            X        Y STABR          LEA_NAME  \
# 0 -86.206200  34.2602    AL  Albertville City
# 1 -86.204900  34.2622    AL  Albertville City
# 2 -86.220100  34.2733    AL  Albertville City
# 3 -86.221806  34.2527    AL  Albertville City
# 4 -86.193300  34.2898    AL  Albertville City
#
#                             SCH_NAME        LCITY LSTATE   LZIP LZIP4  \
# 0          Albertville Middle School  Albertville     AL  35950
# 1            Albertville High School  Albertville     AL  35950  2322
# 2    Albertville Intermediate School  Albertville     AL  35950  1300
# 3      Albertville Elementary School  Albertville     AL  35950
# 4  Albertville Kindergarten and PreK  Albertville     AL  35951  3927
#
#            PHONE  ...  MEMBER   FTE STUTERATIO AMALM AMALF   AM ASALM ASALF  \
# 0  (256)878-2341  ...   908.0  42.0      21.62   1.0   1.0  2.0   0.0   4.0
# 1  (256)894-5000  ...  1606.0  82.0      19.59   1.0   0.0  1.0   4.0   2.0
# ...

# %%
columns_to_drop = ['LZIP4', 'PHONE', 'MEMBER', 'FTE', 'STUTERATIO', 'AMALF', 'AM', 'ASALM', 'ASALF', 'LATCOD', 'LONCOD']
data_frame = data_frame.drop(columns_to_drop, axis=1)
data_frame.head()
# Out:
#            X        Y STABR          LEA_NAME  \
# 0 -86.206200  34.2602    AL  Albertville City
# 1 -86.204900  34.2622    AL  Albertville City
# 2 -86.220100  34.2733    AL  Albertville City
# 3 -86.221806  34.2527    AL  Albertville City
# 4 -86.193300  34.2898    AL  Albertville City
#
#                             SCH_NAME        LCITY LSTATE   LZIP CHARTER_TEXT  \
# 0          Albertville Middle School  Albertville     AL  35950           No
# 1            Albertville High School  Albertville     AL  35950           No
# 2    Albertville Intermediate School  Albertville     AL  35950           No
# 3      Albertville Elementary School  Albertville     AL  35950           No
# 4  Albertville Kindergarten and PreK  Albertville     AL  35951           No
#
#   MAGNET_TEXT  ...    G10    G11    G12 G13  UG  AE  TOTMENROL TOTFENROL  \
# 0          No  ...    NaN    NaN    NaN NaN NaN NaN        NaN       NaN
# 1          No  ...  427.0  384.0  374.0 NaN NaN NaN        NaN       NaN
# ...

# %%
columns_to_drop = ['CHARTER_TEXT', 'MAGNET_TEXT', 'G10','G11', 'G12', 'G13', 'UG', 'AE', 'TOTMENROL', 'TOTFENROL', 'TOTAL', 'AMALM']
data_frame = data_frame.drop(columns_to_drop, axis=1)
data_frame.head()
# Out:
#            X        Y STABR          LEA_NAME  \
# 0 -86.206200  34.2602    AL  Albertville City
# 1 -86.204900  34.2622    AL  Albertville City
# 2 -86.220100  34.2733    AL  Albertville City
# 3 -86.221806  34.2527    AL  Albertville City
# 4 -86.193300  34.2898    AL  Albertville City
#
#                             SCH_NAME        LCITY LSTATE   LZIP      VIRTUAL  \
# 0          Albertville Middle School  Albertville     AL  35950  Not Virtual
# 1            Albertville High School  Albertville     AL  35950  Not Virtual
# 2    Albertville Intermediate School  Albertville     AL  35950  Not Virtual
# 3      Albertville Elementary School  Albertville     AL  35950  Not Virtual
# 4  Albertville Kindergarten and PreK  Albertville     AL  35951  Not Virtual
#
#   GSLO  ...     KG G01 G02    G03    G04    G05    G06    G07    G08    G09
# 0   07  ...    NaN NaN NaN    NaN    NaN    NaN    NaN  469.0  439.0    NaN
# ...

# %%
columns_to_drop = ['VIRTUAL', 'GSLO', 'KG', 'G01', 'G02', 'G03', 'G04', 'G05', 'G06', 'G07', 'G08', 'G09']
data_frame = data_frame.drop(columns_to_drop, axis=1)
data_frame.head()
# Out:
#            X        Y STABR          LEA_NAME  \
# 0 -86.206200  34.2602    AL  Albertville City
# 1 -86.204900  34.2622    AL  Albertville City
# 2 -86.220100  34.2733    AL  Albertville City
# 3 -86.221806  34.2527    AL  Albertville City
# 4 -86.193300  34.2898    AL  Albertville City
#
#                             SCH_NAME        LCITY LSTATE   LZIP GSHI  \
# 0          Albertville Middle School  Albertville     AL  35950   08
# 1            Albertville High School  Albertville     AL  35950   12
# 2    Albertville Intermediate School  Albertville     AL  35950   06
# 3      Albertville Elementary School  Albertville     AL  35950   04
# 4  Albertville Kindergarten and PreK  Albertville     AL  35951   KG
#
#   SCHOOL_LEVEL  ... STITLEI STATUS  SCHOOL_TYPE_TEXT          SY_STATUS_TEXT  \
# 0       Middle  ...   1-Yes      1    Regular school  Currently operational
# 1         High  ...   1-Yes      1    Regular school  Currently operational
# ...

# %%
columns_to_drop = ['GSHI', 'SCHOOL_LEVEL', 'STITLEI', 'STATUS', 'SCHOOL_TYPE_TEXT', 'SY_STATUS_TEXT', 'ULOCALE', 'NMCNTY', 'TOTFRL', 'FRELCH', 'REDLCH', 'PK']
data_frame = data_frame.drop(columns_to_drop, axis=1)
data_frame.head()
# Out:
#            X        Y STABR          LEA_NAME  \
# 0 -86.206200  34.2602    AL  Albertville City
# 1 -86.204900  34.2622    AL  Albertville City
# 2 -86.220100  34.2733    AL  Albertville City
# 3 -86.221806  34.2527    AL  Albertville City
# 4 -86.193300  34.2898    AL  Albertville City
#
#                             SCH_NAME        LCITY LSTATE   LZIP TITLEI
# 0          Albertville Middle School  Albertville     AL  35950  1-Yes
# 1            Albertville High School  Albertville     AL  35950  1-Yes
# 2    Albertville Intermediate School  Albertville     AL  35950  1-Yes
# 3      Albertville Elementary School  Albertville     AL  35950  1-Yes
# 4  Albertville Kindergarten and PreK  Albertville     AL  35951  1-Yes

# %%
columns_to_drop = ['X', 'Y']
data_frame = data_frame.drop(columns_to_drop, axis=1)
data_frame.head()
# Out:
#   STABR          LEA_NAME                           SCH_NAME        LCITY  \
# 0    AL  Albertville City          Albertville Middle School  Albertville
# 1    AL  Albertville City            Albertville High School  Albertville
# 2    AL  Albertville City    Albertville Intermediate School  Albertville
# 3    AL  Albertville City      Albertville Elementary School  Albertville
# 4    AL  Albertville City  Albertville Kindergarten and PreK  Albertville
#
#   LSTATE   LZIP TITLEI
# 0     AL  35950  1-Yes
# 1     AL  35950  1-Yes
# 2     AL  35950  1-Yes
# 3     AL  35950  1-Yes
# 4     AL  35951  1-Yes

# %%
#rename columns
new_column_names = {'SCH_NAME': 'sCHOOL_NAME', 'LCITY': 'CITY', 'LSTATE': 'STATE', 'LZIP': 'ZIP'}
data_frame.rename(columns=new_column_names, inplace=True)

# %%
columns_to_drop = ['LEA_NAME', 'STATE']
data_frame = data_frame.drop(columns_to_drop, axis=1)
data_frame.head()
# Out:
#   STABR                        sCHOOL_NAME         CITY    ZIP TITLEI
# 0    AL          Albertville Middle School  Albertville  35950  1-Yes
# 1    AL            Albertville High School  Albertville  35950  1-Yes
# 2    AL    Albertville Intermediate School  Albertville  35950  1-Yes
# 3    AL      Albertville Elementary School  Albertville  35950  1-Yes
# 4    AL  Albertville Kindergarten and PreK  Albertville  35951  1-Yes

# %%
data_frame.rename(columns={'sCHOOL_NAME': 'SCHOOL_NAME'}, inplace=True)

# %%
data_frame
# Out:
#        STABR                        SCHOOL_NAME          CITY    ZIP TITLEI
# 0         AL          Albertville Middle School   Albertville  35950  1-Yes
# 1         AL            Albertville High School   Albertville  35950  1-Yes
# 2         AL    Albertville Intermediate School   Albertville  35950  1-Yes
# 3         AL      Albertville Elementary School   Albertville  35950  1-Yes
# 4         AL  Albertville Kindergarten and PreK   Albertville  35951  1-Yes
# ...      ...                                ...           ...    ...    ...
# 100717    VI         LOCKHART ELEMENTARY SCHOOL  Saint Thomas    802  1-Yes
# 100718    VI    ULLA F MULLER ELEMENTARY SCHOOL  Saint Thomas    802  1-Yes
# 100719    VI    YVONNE BOWSKY ELEMENTARY SCHOOL  Saint Thomas    802  1-Yes
# 100720    VI         CANCRYN JUNIOR HIGH SCHOOL  Saint Thomas    804  1-Yes
# 100721    VI       BERTHA BOSCHULTE JUNIOR HIGH  Saint Thomas    802  1-Yes
#
# [100722 rows x 5 columns]

# %%
columns_to_drop = ['TITLEI']
data_frame = data_frame.drop(columns_to_drop, axis=1)
data_frame.head()
# Out:
#   STABR                        SCHOOL_NAME         CITY    ZIP
# 0    AL          Albertville Middle School  Albertville  35950
# 1    AL            Albertville High School  Albertville  35950
# 2    AL    Albertville Intermediate School  Albertville  35950
# 3    AL      Albertville Elementary School  Albertville  35950
# 4    AL  Albertville Kindergarten and PreK  Albertville  35951

# %%
data_frame.rename(columns={'STABR': 'STATE'}, inplace=True)
data_frame.head()
# Out:
#   STATE                        SCHOOL_NAME         CITY    ZIP
# 0    AL          Albertville Middle School  Albertville  35950
# 1    AL            Albertville High School  Albertville  35950
# 2    AL    Albertville Intermediate School  Albertville  35950
# 3    AL      Albertville Elementary School  Albertville  35950
# 4    AL  Albertville Kindergarten and PreK  Albertville  35951

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100722 entries, 0 to 100721
# Data columns (total 4 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   STATE        100722 non-null  object
#  1   SCHOOL_NAME  100722 non-null  object
#  2   CITY         100722 non-null  object
#  3   ZIP          100722 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 3.1+ MB

# %%
# Replace 'new_file_path.csv' with the desired path and filename for the new CSV file.
new_file_path = 'Clean3_Public_School_Characteristics_2020-21.csv'

# Use the to_csv() method to save the DataFrame to a new CSV file.
data_frame.to_csv(new_file_path, index=False)
